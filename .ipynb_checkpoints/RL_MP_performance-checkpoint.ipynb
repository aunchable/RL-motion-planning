# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = np.loadtxt("./logging/logs.txt",delimiter=",")
plt.plot(data[:,0])
plt.show()
plt.plot(data[:,1])
plt.show()
plt.plot(data[:,2])
plt.show()
plt.plot(data[:,3])
plt.show()
